# %%
import pandas as pd

# %%
data = pd.read_csv("../data/internship_data.csv")

# %%
data.head()
# Out:
#                                        Job Title  \
# 0                                  Ruby On Rails
# 1  Sharepoint Developer - Operational Excellence
# 2                         Mobile App Development
# 3                          Front End Development
# 4                      Compute Platform Engineer
#
#                                             Job link              Company  \
# 0  https://internshala.com/internship/detail/ruby...          PlanetSpark
# 1  https://internshala.com/internship/detail/shar...               Abbott
# 2  https://internshala.com/internship/detail/mobi...          Thomas Cook
# 3  https://internshala.com/internship/detail/fron...      Ghar Pe Shiksha
# 4  https://internshala.com/internship/detail/work...  Corteva Agriscience
#
#                 location    Category
# 0  Delhi, Gurgaon, Noida  Internship
# 1                 Mumbai  Internship
# 2                 Mumbai  Internship
# 3                  Delhi  Internship
# 4         Work from home  Internship

# %%
data.drop(['Category'],axis = 1,inplace = True)

# %%
data['Job Title'].shape
# Out:
# (1164,)

# %%
data.head()
# Out:
#                                        Job Title  \
# 0                                  Ruby On Rails
# 1  Sharepoint Developer - Operational Excellence
# 2                         Mobile App Development
# 3                          Front End Development
# 4                      Compute Platform Engineer
#
#                                             Job link              Company  \
# 0  https://internshala.com/internship/detail/ruby...          PlanetSpark
# 1  https://internshala.com/internship/detail/shar...               Abbott
# 2  https://internshala.com/internship/detail/mobi...          Thomas Cook
# 3  https://internshala.com/internship/detail/fron...      Ghar Pe Shiksha
# 4  https://internshala.com/internship/detail/work...  Corteva Agriscience
#
#                 location
# 0  Delhi, Gurgaon, Noida
# 1                 Mumbai
# 2                 Mumbai
# 3                  Delhi
# 4         Work from home

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1164 entries, 0 to 1163
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Job Title  1136 non-null   object
#  1   Job link   1136 non-null   object
#  2   Company    1136 non-null   object
#  3   location   1136 non-null   object
# dtypes: object(4)
# memory usage: 36.5+ KB

# %%
data.isnull().sum()
# Out:
# Job Title    28
# Job link     28
# Company      28
# location     28
# dtype: int64

# %%
data.drop_duplicates(inplace= True)

# %%
data.shape
# Out:
# (935, 4)

# %%
data['Job Title'].unique()
# Out:
# array(['Ruby On Rails', 'Sharepoint Developer - Operational Excellence',
#        'Mobile App Development', 'Front End Development',
#        'Compute Platform Engineer', 'Software Development', 'QA',
#        'Wordpress (Elementor)', 'Android App Development', nan,
#        'Web Development', 'WordPress Development',
#        'Python Developer For Data Scrapping', 'Python Development',
#        'React Native Development', 'Developer', 'Laravel Developer',
#        'Product Management', 'Flutter Developer',
#        'Associate Product Manager', 'Flutter Development',
#        'MLOps and AI Infra', 'Game Development', 'Full Stack Development',
#        'Unity Game Developer', 'Language QA Analyst (Gujarati)',
#        'Blockchain Trainee', 'Shopify & Website Management',
#        'AI Automation & Vibe Coding (Prompt Engineering + Tiny Tool Building)',
#        'Computer Vision', 'QA Testing', 'MERN Stack With NestJS',
#        'MERN Full Stack', 'Quality Analyst', 'MERN Stack Developer',
#        'Microsoft Dynamics 365 Developer', 'Manual Testing',
#        'Digital Marketing', 'Internet Of Things (IoT)', 'Project Manager',
#        'Backend Development', 'AI Agent Development', 'Remote Sensing',
#        'Frontend Developer - NextJS', 'AI Software Development',
#        'Quality Assurance Tester – Voice AI & Web',
#        'Catalog Management Apprenticeship',
#        'Software Testing (Automation + Manual)',
#        'Wix Website Developer (No Code) Wix Studio',
#        'Software Development Engineering (Web)', 'ReactJS Development',
#        'PHP Development', 'Subject Matter Expert (SME)',
#        'Content Writing (Research Associate In Computer Sciecne)',
#        'Java Development', 'iOS App Development', 'Teaching',
#        'MySQL & Data Science Development',
#        'React Native Development (For Community App)',
#        'Shopify Website Intern – Build A Store That Actually Converts',
#        'Power BI Intern (GJEPC India, BKC)', 'Backend Developer',
#        'Software Engineer - Frontend', 'FPV Drone Pilot And Developer',
#        'UX/UI Design', 'AI Engineer', 'AI and ML',
#        'Competitive Programming Teaching', 'SAP Software Consultant',
#        'Laravel/Livewire Developer', 'AI Storytelling',
#        'Unity Game Development', 'Production Manager',
#        'React Native, NextJS And Firebase Development',
#        'No-Code Systems & Automation', 'Node.js Development',
#        'Android Developer', 'Wordpress Elementor Web Designer',
#        'Data Science AI&ML Python Research', '.NET Developer', 'DevOps',
#        'Laravel Development', 'Software Testing',
#        'Full Stack Blockchain Development', 'Full Stack DevOps Engineer',
#        'Platform Engineering', 'Javascript Developer',
#        'Innovative Judiciary Prelims Quiz Maker',
#        'Electronic Product Developement',
#        'Internal IT General Control Testing', 'Python And Generative AI',
#        'Technology Education & GenAI Intern', 'Product Growth Manager',
#        'Cyber Security', 'Automation Testing',
#        'NestJS API Developer - AI & Recommendation Systems',
#        'WordPress Development (Female Only)',
#        'NestJS API Developer - Marketplace, Wallet & Payments',
#        'NestJS API Developer - System Architect & Auth Lead',
#        'NestJS API Developer - WhatsApp, Sockets, Chat',
#        'Backend Development (PHP)', 'AI-CRYPTO Transactions Tracking',
#        'Content and Social Media Marketing Manager',
#        'AI Content Marketing',
#        'AI Native Fintech App Product (UX, Functional Requirements, QA)',
#        'Pine Script Coder For TradingView (Expert)',
#        'Expert IONIC App Developer',
#        'Website Development (Shopify/WordPress/Frontend)',
#        'Online Teacher - Programming', 'Artificial Intelligence (AI)',
#        'Computer Vision And Image Processing', 'iOS Developer',
#        'Proposal Writing & Automation Support',
#        'Flutter Frontend Development', 'Unreal Engine - Game Design',
#        'PHP Developer', 'Embedded Developer', 'DevOps Engineer',
#        'R&D - New Product Development', 'MERN Stack', 'Unreal Developer',
#        'Odoo Python Developer', 'Content & E-Commerce Management',
#        'AIML Engineer', 'Junior Software Developer',
#        'Ionic App Development', 'Cloud Computing Mentor',
#        'Software Testing And Quality Assurance',
#        'Mobile App Frontend Developer', 'Mobile App Backend Developer',
#        'Mobile App Developer', 'Flutter App Development', 'React Native',
#        'Software Developer', 'Full Stack Developer', 'Shopify Developer',
#        'STEM Trainer', 'Rust Developer', 'Web Developer (React)',
#        'C++ Development',
#        'Mobile App Development (Flutter/React Native/Android/iOS)',
#        'Data Engineer', 'Content Editor',
#        'UI/UX Design & Developer (Framer)', 'Computer Operator',
#        'Laravel Framework Engineer',
#        'Product Development – Embedded & Electronics', 'IT Recruiter',
#        'AI Innovation Trainer', 'GenAI/LLM', 'JavaScript Development',
#        'Cloud Infrastructure Management',
#        'Quality & Evaluation For Web App (use LLM AI Tools)',
#        'Full Stack Developer (use LLM AI Tools)',
#        'Tech & Digital Operations', 'Kotlin App Development',
#        'MERN Stack Development', 'Shopify Web Development',
#        'STEM Instructor', 'IT Support Engineer',
#        'Wix Website Development', 'Technical Assistant',
#        'Cloud Computing', 'Android App Developer',
#        'Front End & Game Developer', 'Go Developer',
#        'ML/AI Software Developer', 'Shopify Development', 'Web Developer',
#        'Product Testing', 'Backend Automation',
#        'Full Stack(AI/ML) Engineer', '.NET Development',
#        'Unreal Engine Developer (Game)', 'Django Development',
#        'Programming', 'SQL Programmer',
#        'Python/Django & React Engineering', 'UI/UX Design',
#        'Desktop App Development (Python)',
#        'Computer Vision (Image Processing)',
#        'Content Creator For Java, Python, MySql, Cyber Security Using Canva',
#        'Data Automation', 'Cloud And Backend Development',
#        'Multiplayer Game Development', 'UI UX / IOS Testing',
#        'Computer Operator & Admin Support', 'Framer Web Development',
#        'Blockchain Development', 'IPhone Pro 3D Capture Specialist',
#        'Data Scientist', 'Android & IoT Development',
#        'Node.js Backend Developer', 'React Developer',
#        'AI/ML Developer - Python',
#        'React Native Development (iOS APP Development)',
#        'Founding Engineer', 'System Admin', 'Python Developer',
#        'IT Skills', 'Mutual Fund Research And Operations Intern',
#        'GPU Mining Infrastructure Manager',
#        'WordPress Website Management', 'Website Designer', 'Sales',
#        'Machine Learning', 'Full Stack Web Development (REST)',
#        'n8n Automation', 'AWS DevOps', 'Angular.js Development',
#        'AI & Automation', 'Wordpress Developer', 'MERN Stack Trainee',
#        'Game Designer', 'Technical Trainee', 'AI/ML', 'Linux Engineer',
#        'Cloud Engineer', 'Research Associate', 'XML & Search',
#        'Business Associate (No-Code App Development & Customer Success)',
#        'UI/UX Design (App + Web + Admin Panel)',
#        'Software Development (SDLC, SQL,HTML)', 'Azure DevOps',
#        'Environment Design', 'Unity Asset Artist', 'Salesforce Developer',
#        'Shopify & WordPress Development', 'Django Developer',
#        'Chemistry & Life Sciences', 'SAP Management',
#        'Software Engineering (Python, React)',
#        'Software Engineering (React Native)',
#        'Full-Stack Web Development (Frontend + Backend) - Tech Intern/ Application Developer',
#        'GoLang Developer', 'Customer Relation & Support',
#        'Unity Developer',
#        'Python Development (ERPNext & Frappe Framework)',
#        'Mobile Game Developer', 'Online Scala Programming Tutor',
#        'WordPress Implementation Specialist', 'Digital Transformation',
#        'Kotlin Development', 'PHP Trainee',
#        'Automation & Program Operations', 'Software Quality Assurance',
#        'Shopify App Developer', 'Whatsapp Integration',
#        'Web Development And Digital Marketing Manager',
#        'React JS Developer', 'UI/UX & WordPress Development',
#        'Data Integration', 'Database Building/Management',
#        'Information Technology',
#        'Data Annotation/Labelling (Computer Vision-Image Data)',
#        'AI, LLM, Chatbot based search engine Internsnhip',
#        'Next JS Development', 'Rasa Bot Development', 'SQL DEVELOPER',
#        'AI Engineering', 'Product Marketing Management', '2D Animation',
#        'Security Operations Center - Cyber Security (2025 or Prior Passout)',
#        'Python Programming', 'Embedded Software Engineering',
#        'Visual Design', 'E-commerce Executive',
#        'R Programming Online Tutor',
#        'Photo Collection Field Job – Bangalore (No Sales)',
#        'Summer Project', 'IPhone Object Scanning Intern (Remote)',
#        '3D Character Animator – Avatar Development',
#        'WordPress Web Development', 'QC - Hindi Transcription',
#        'SAP BI (Business Intelligence) & Analytics', 'SAP Finance',
#        'Shopify Store Creator', 'AI/Tech',
#        'Research (Business, Market, Economics & AI)',
#        'Linux & Kubernetes Development', 'Tech Support Strategist',
#        'On-Field Project Manager', 'Project Coordinator (IT)', 'GenAI',
#        'Angular Development', 'AI/ML Engineer', 'Back End Developer',
#        'Front End Developer', 'SAP ABAP', 'IT Support',
#        'Python Backend Developer', 'UI/UX Development and Qt Framework',
#        'Automation Anywhere Bot Maintenance & Operations',
#        'Game Development Instructor',
#        'Web/Extension Development, Android App Development',
#        'Mobile App Testing', 'PowerApps Developer',
#        'Software Analyst (eCommerce)',
#        'STEM trainer/Robotics trainer/STEM Educator',
#        'Cyber Security - Penetration Testing',
#        'Cloud & DevOps Engineering', 'Chromium C/C++ Development',
#        'Website Developer (Wix Platform)',
#        'GAS (Google App Script) For Front End And Custom Interface Using Google Sheets',
#        'Software Engineering (Devops)', 'Angular Developer',
#        'Data (Python & SQL)',
#        'Full Stack Software Development And Support',
#        'Tech Operations - Study Abroad', 'Robotics Engineer',
#        'React Native Developer', 'Online Teaching (Full Stack)',
#        'Game Developer', 'Robotics',
#        'Software Engineering (Python + LLM Agents)',
#        'Mathematics and Computing', 'AI & Python Developer',
#        'WordPress Develoment', 'Junior WordPress Development',
#        'C/C++ Qt Development', 'Systems Development Engineer',
#        'Automation Specialist', 'Automation Expert',
#        'Automation Engineering – POS & Inventory Management Systems',
#        'Full Stack AI Engineer - Intern',
#        'Founding Full Stack Role - OutFlo.io (IIT Kharagpur Alum)',
#        'Product & Partnerships ( Entrepreneur In Residence)',
#        'Data Labeling', 'Technical Support Representative Intern',
#        'Field Engineer Apprentice', 'Field Engineer',
#        'Risk Advisory Trainee', 'LLVM and MLIR Compiler Engineer Intern',
#        'Entry-Level Data Analytics Role', 'Research',
#        'Information Security Engineer', 'Field Engineer_DET',
#        'Non-Tech Intern BS', 'Interim Engineering Intern – Software',
#        'Software Development Engineer I, Amazon University Talent Acquisition',
#        'Software Development Engineer I – Amazon University Talent Acquisition',
#        'Trainee', 'Student Intern', 'PNP Intern Performance',
#        'Technical Support Professional Intern',
#        'Hardware Engineer Intern', 'Interim Engineering Intern'],
#       dtype=object)

# %%
internship_categories = {
    "Software and web Development": [
        "angular","full stack", "python", "software development","developer", "software engineer","react","native","Front End",
        "development engineer", "founding", "interim", "junior software","kotlin","development",
        "trainee", "flutter", "mern", "kotlin", "frontend", "backend","php","Product Development","c","c++","django","java", "web", "wordpress", "react", "native", "js", "app","microsoft","laravel","Development Engineer",".net"
    ],
    "AI / ML / Data Science": [
        "ml", "genai", "ai", "llm","bot", "chatbot", "data automation",
        "data scientist", "data analytics", "llvm", "compiler", "research","sql",
        "computer vision", "analyst","data","mathematics"
    ],
    "Cloud, DevOps & Infrastructure": [
        "cloud", "aws", "azure", "devops", "infrastructure"
    ],
    "Game & Graphics Development": [
        "game", "unity", "unreal", "3d", "animator","2D"
    ],
    "Cybersecurity & InfoSec": [
        "cyber security", "penetration testing", "infosec", "security operations",
        "information security"
    ],
    "Embedded Systems & Hardware": [
        "embedded", "electronics", "field engineer", "hardware" , 'iot'
    ],
    "UI/UX & Design": [
        "ui","ux", "user interface", "user experience", "design", "ui design",
        "ui designer", "ux researcher", "visual design", "interface"
    ],
    "Testing & QA": [
        "software testing", "quality assurance", "qa", "manual testing","testing"
        "automation testing", "mobile app testing","management","IT support","system admin"
    ],
    "Training & Teaching": [
        "trainer", "instructor", "teaching", "tutor", "mentor", "game development instructor","instructor"
    ],
    "Business, Content & Misc": [
        "marketing", "business associate", "proposal", "content","entrepreneur","entrepreneurship",
        "wordpress implementation", "sales", "digital transformation",
        "photo collection", "pnp", "non-tech", "student", "technical support"
    ]
}

def extract_category(title):
    title = str(title).lower().strip()
    for cat, words in internship_categories.items():
        for keyword in words:
            if keyword.lower() in title:
                return cat
    return "Others"

data['Category'] = data['Job Title'].apply(extract_category)

# %%
data['Category'].value_counts()
# Out:
# Category
# Software and web Development      820
# Testing & QA                       36
# AI / ML / Data Science             32
# Others                             12
# Business, Content & Misc           11
# Embedded Systems & Hardware         7
# UI/UX & Design                      6
# Cloud, DevOps & Infrastructure      6
# Game & Graphics Development         4
# Training & Teaching                 1
# Name: count, dtype: int64

# %%
data[data['Category'] == 'AI / ML / Data Science']
# Out:
#                            Job Title  \
# 0                      Ruby On Rails
# 23                MLOps and AI Infra
# 29    Language QA Analyst (Gujarati)
# 41                   Quality Analyst
# 73                   Quality Analyst
# 91                   Quality Analyst
# 111                      AI Engineer
# 113                        AI and ML
# 120                  AI Storytelling
# 148                  Quality Analyst
# 152                  Quality Analyst
# 404                  Quality Analyst
# 426                    AIML Engineer
# 514                  Quality Analyst
# 522                     STEM Trainer
# 546                  Quality Analyst
# 551                    Data Engineer
# 570            AI Innovation Trainer
# 579                        GenAI/LLM
# 651                   SQL Programmer
# 679                  Data Automation
# 732                  Quality Analyst
# 767                  AI & Automation
# 780                            AI/ML
# 868                 Data Integration
# 869     Database Building/Management
# 901                   AI Engineering
# 923                   AI Engineering
# 926                  Quality Analyst
# 984                            GenAI
# 988                   AI/ML Engineer
# 1134                   Data Labeling
#
#                                                Job link  \
# 0     https://internshala.com/internship/detail/ruby...
# 23    https://internshala.com/internship/detail/work...
# 29    https://internshala.com/internship/detail/work...
# 41    https://internshala.com/internship/detail/qual...
# 73    https://internshala.com/internship/detail/qual...
# 91    https://internshala.com/internship/detail/work...
# 111   https://internshala.com/internship/detail/work...
# 113   https://internshala.com/internship/detail/ai-a...
# 120   https://internshala.com/internship/detail/work...
# 148   https://internshala.com/internship/detail/part...
# 152   https://internshala.com/internship/detail/qual...
# 404   https://internshala.com/internship/detail/qual...
# 426   https://internshala.com/internship/detail/aiml...
# 514   https://internshala.com/internship/detail/work...
# 522   https://internshala.com/internship/detail/stem...
# 546   https://internshala.com/internship/detail/qual...
# 551   https://internshala.com/internship/detail/work...
# 570   https://internshala.com/internship/detail/ai-i...
# 579   https://internshala.com/internship/detail/work...
# 651   https://internshala.com/internship/detail/work...
# 679   https://internshala.com/internship/detail/data...
# 732   https://internshala.com/internship/detail/qual...
# 767   https://internshala.com/internship/detail/work...
# 780   https://internshala.com/internship/detail/work...
# 868   https://internshala.com/internship/detail/data...
# 869   https://internshala.com/internship/detail/data...
# 901   https://internshala.com/internship/detail/work...
# 923   https://internshala.com/internship/detail/work...
# 926   https://internshala.com/internship/detail/qual...
# 984   https://internshala.com/internship/detail/work...
# 988   https://internshala.com/internship/detail/work...
# 1134  https://internshala.com/internship/detail/work...
#
#                                                 Company  \
# 0                                           PlanetSpark
# 23                                            Fx31 Labs
# 29                                         Supernova AI
# 41                           Kadel Labs Private Limited
# 73                   Techdome Solutions Private Limited
# 91                                         Jarurat Care
# 111                                     The Email Mafia
# 113   Predusk Technology Private Limited (Brand Name...
# 120           DeepThought CultureTech Ventures Pvt Ltd.
# 148                 Medius Technologies Private Limited
# 152                    FynTune Solution Private Limited
# 404                                          GoMechanic
# 426                       Subash Vijay Associates (SVA)
# 514                Resolute AI Software Private Limited
# 522                                              Edtech
# 546                                  Mind Loop Soutions
# 551                                          FiftySeven
# 570                                       Main Marshals
# 579                Resolute AI Software Private Limited
# 651                       NDFM Business World Pvt. Ltd.
# 679             Stanza Shipping (India) Private Limited
# 732                                           Accredian
# 767                                          MyGigsters
# 780                  Trivy Technologies Private Limited
# 868                                          ExactSpace
# 869                                   SaShr Consultants
# 901                             Enshrine Global Systems
# 923                                        Icecreamlabs
# 926                    FynTune Solution Private Limited
# 984                               Quantum IT Innovation
# 988                                              Bditto
# 1134   Precision Design And Engineering Private Limited
#
#                                                location  \
# 0                                 Delhi, Gurgaon, Noida
# 23                                       Work from home
# 29                                       Work from home
# 41                                              Udaipur
# 73                                    Indore, Hyderabad
# 91                                       Work from home
# 111                                      Work from home
# 113                                              Jaipur
# 120                                      Work from home
# 148                          Thane, Navi Mumbai, Mumbai
# 152                          Thane, Navi Mumbai, Turbhe
# 404                                             Gurgaon
# 426                                              Mumbai
# 514                                      Work from home
# 522                                            Siliguri
# 546                                                Pune
# 551                                      Work from home
# 570                                             Lucknow
# 579                                      Work from home
# 651                                      Work from home
# 679                                               Delhi
# 732   Gurgaon                                       ...
# 767                                      Work from home
# 780                                      Work from home
# 868                                           Bangalore
# 869                                              Mumbai
# 901                                      Work from home
# 923                                      Work from home
# 926                          Thane, Navi Mumbai, Turbhe
# 984                                      Work from home
# 988                                      Work from home
# 1134                                     Work from home
#
#                     Category
# 0     AI / ML / Data Science
# 23    AI / ML / Data Science
# 29    AI / ML / Data Science
# 41    AI / ML / Data Science
# 73    AI / ML / Data Science
# 91    AI / ML / Data Science
# 111   AI / ML / Data Science
# 113   AI / ML / Data Science
# 120   AI / ML / Data Science
# 148   AI / ML / Data Science
# 152   AI / ML / Data Science
# 404   AI / ML / Data Science
# 426   AI / ML / Data Science
# 514   AI / ML / Data Science
# 522   AI / ML / Data Science
# 546   AI / ML / Data Science
# 551   AI / ML / Data Science
# 570   AI / ML / Data Science
# 579   AI / ML / Data Science
# 651   AI / ML / Data Science
# 679   AI / ML / Data Science
# 732   AI / ML / Data Science
# 767   AI / ML / Data Science
# 780   AI / ML / Data Science
# 868   AI / ML / Data Science
# 869   AI / ML / Data Science
# 901   AI / ML / Data Science
# 923   AI / ML / Data Science
# 926   AI / ML / Data Science
# 984   AI / ML / Data Science
# 988   AI / ML / Data Science
# 1134  AI / ML / Data Science

# %%
data.to_csv("../data/internship_data_cleaned.csv")
